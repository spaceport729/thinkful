# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
artworks = pd.read_csv('https://media.githubusercontent.com/media/MuseumofModernArt/collection/master/Artworks.csv')

# %%
artworks.columns
# Out:
# Index(['Title', 'Artist', 'ConstituentID', 'ArtistBio', 'Nationality',
#        'BeginDate', 'EndDate', 'Gender', 'Date', 'Medium', 'Dimensions',
#        'CreditLine', 'AccessionNumber', 'Classification', 'Department',
#        'DateAcquired', 'Cataloged', 'ObjectID', 'URL', 'ThumbnailURL',
#        'Circumference (cm)', 'Depth (cm)', 'Diameter (cm)', 'Height (cm)',
#        'Length (cm)', 'Weight (kg)', 'Width (cm)', 'Seat Height (cm)',
#        'Duration (sec.)'],
#       dtype='object')

# %%
# Select Columns.
artworks = artworks[['Artist', 'Nationality', 'Gender', 'Date', 'Department',
                    'DateAcquired', 'URL', 'ThumbnailURL', 'Height (cm)', 'Width (cm)']]

# Convert URL's to booleans.
artworks['URL'] = artworks['URL'].notnull()
artworks['ThumbnailURL'] = artworks['ThumbnailURL'].notnull()

# Drop films and some other tricky rows.
artworks = artworks[artworks['Department']!='Film']
artworks = artworks[artworks['Department']!='Media and Performance Art']
artworks = artworks[artworks['Department']!='Fluxus Collection']

# Drop missing data.
artworks = artworks.dropna()

# %%
artworks.head(n=100)
# Out:
#                                         Artist                    Nationality  \
# 0                                  Otto Wagner                     (Austrian)
# 1                     Christian de Portzamparc                       (French)
# 2                                   Emil Hoppe                     (Austrian)
# 3                              Bernard Tschumi                             ()
# 4                                   Emil Hoppe                     (Austrian)
# 5                              Bernard Tschumi                             ()
# 6                              Bernard Tschumi                             ()
# 7                              Bernard Tschumi                             ()
# 8                              Bernard Tschumi                             ()
# 9                              Bernard Tschumi                             ()
# 10                             Bernard Tschumi                             ()
# 11                             Bernard Tschumi                             ()
# 12                             Bernard Tschumi                             ()
# 13                             Bernard Tschumi                             ()
# 14                             Bernard Tschumi                             ()
# 15                             Bernard Tschumi                             ()
# 16                             Bernard Tschumi                             ()
# 17                             Bernard Tschumi                             ()
# 18                             Bernard Tschumi                             ()
# 19                             Bernard Tschumi                             ()
# 20                             Bernard Tschumi                             ()
# 21                             Bernard Tschumi                             ()
# 22                             Bernard Tschumi                             ()
# 23                             Bernard Tschumi                             ()
# 24                             Bernard Tschumi                             ()
# 25                             Bernard Tschumi                             ()
# 26                             Bernard Tschumi                             ()
# 27                             Bernard Tschumi                             ()
# 28                             Bernard Tschumi                             ()
# 29                             Bernard Tschumi                             ()
# ..                                         ...                            ...
# 70                             Bernard Tschumi                             ()
# 71                              Roger C. Ferri                     (American)
# 72                              Michael Graves                     (American)
# 73                              Michael Graves                     (American)
# 74                              Michael Graves                     (American)
# 75                              Michael Graves                     (American)
# 76   Aldo Rossi, Gianni Braghieri, M. Bosshard  (Italian) (Italian) (Italian)
# 78                         Erik Gunnar Asplund                      (Swedish)
# 79                         Erik Gunnar Asplund                      (Swedish)
# 80                         Erik Gunnar Asplund                      (Swedish)
# 81                         Erik Gunnar Asplund                      (Swedish)
# 82                         Erik Gunnar Asplund                      (Swedish)
# 83                         Erik Gunnar Asplund                      (Swedish)
# 84                         Erik Gunnar Asplund                      (Swedish)
# 85                         Erik Gunnar Asplund                      (Swedish)
# 86                         Erik Gunnar Asplund                      (Swedish)
# 87                         Erik Gunnar Asplund                      (Swedish)
# 88                         Erik Gunnar Asplund                      (Swedish)
# 89                         Erik Gunnar Asplund                      (Swedish)
# 90                         Erik Gunnar Asplund                      (Swedish)
# 91                         Erik Gunnar Asplund                      (Swedish)
# 92                         Erik Gunnar Asplund                      (Swedish)
# 93                         Erik Gunnar Asplund                      (Swedish)
# 94                         Erik Gunnar Asplund                      (Swedish)
# 95                         Erik Gunnar Asplund                      (Swedish)
# 96                         Erik Gunnar Asplund                      (Swedish)
# 97                         Erik Gunnar Asplund                      (Swedish)
# 98                         Erik Gunnar Asplund                      (Swedish)
# 99                         Erik Gunnar Asplund                      (Swedish)
# 100                        Erik Gunnar Asplund                      (Swedish)
#
#                    Gender     Date             Department DateAcquired   URL  \
# 0                  (Male)     1896  Architecture & Design   1996-04-09  True
# 1                  (Male)     1987  Architecture & Design   1995-01-17  True
# 2                  (Male)     1903  Architecture & Design   1997-01-15  True
# 3                  (Male)     1980  Architecture & Design   1995-01-17  True
# 4                  (Male)     1903  Architecture & Design   1997-01-15  True
# 5                  (Male)  1976-77  Architecture & Design   1995-01-17  True
# 6                  (Male)  1976-77  Architecture & Design   1995-01-17  True
# 7                  (Male)  1976-77  Architecture & Design   1995-01-17  True
# 8                  (Male)  1976-77  Architecture & Design   1995-01-17  True
# 9                  (Male)  1976-77  Architecture & Design   1995-01-17  True
# 10                 (Male)  1976-77  Architecture & Design   1995-01-17  True
# 11                 (Male)  1976-77  Architecture & Design   1995-01-17  True
# 12                 (Male)  1976-77  Architecture & Design   1995-01-17  True
# 13                 (Male)  1976-77  Architecture & Design   1995-01-17  True
# 14                 (Male)  1976-77  Architecture & Design   1995-01-17  True
# 15                 (Male)  1976-77  Architecture & Design   1995-01-17  True
# 16                 (Male)  1976-77  Architecture & Design   1995-01-17  True
# 17                 (Male)  1976-77  Architecture & Design   1995-01-17  True
# 18                 (Male)  1976-77  Architecture & Design   1995-01-17  True
# 19                 (Male)  1976-77  Architecture & Design   1995-01-17  True
# 20                 (Male)  1976-77  Architecture & Design   1995-01-17  True
# 21                 (Male)  1976-77  Architecture & Design   1995-01-17  True
# 22                 (Male)  1976-77  Architecture & Design   1995-01-17  True
# 23                 (Male)  1976-77  Architecture & Design   1995-01-17  True
# 24                 (Male)  1976-77  Architecture & Design   1995-01-17  True
# 25                 (Male)  1976-77  Architecture & Design   1995-01-17  True
# 26                 (Male)  1976-77  Architecture & Design   1995-01-17  True
# 27                 (Male)  1976-77  Architecture & Design   1995-01-17  True
# 28                 (Male)  1976-77  Architecture & Design   1995-01-17  True
# 29                 (Male)  1976-77  Architecture & Design   1995-01-17  True
# ..                    ...      ...                    ...          ...   ...
# 70                 (Male)     1986  Architecture & Design   2000-01-19  True
# 71                 (Male)     1979  Architecture & Design   1980-01-08  True
# 72                 (Male)     1978  Architecture & Design   1980-01-08  True
# 73                 (Male)     1978  Architecture & Design   1980-01-08  True
# 74                 (Male)     1978  Architecture & Design   1980-01-08  True
# 75                 (Male)     1978  Architecture & Design   1980-01-08  True
# 76   (Male) (Male) (Male)     1974  Architecture & Design   1980-01-08  True
# 78                 (Male)  c. 1917  Architecture & Design   1990-01-17  True
# 79                 (Male)     1917  Architecture & Design   1990-01-17  True
# 80                 (Male)     1917  Architecture & Design   1990-01-17  True
# 81                 (Male)     1917  Architecture & Design   1990-01-17  True
# 82                 (Male)     1917  Architecture & Design   1990-01-17  True
# 83                 (Male)     1917  Architecture & Design   1990-01-17  True
# 84                 (Male)     1923  Architecture & Design   1990-01-17  True
# 85                 (Male)     1923  Architecture & Design   1990-01-17  True
# 86                 (Male)     1923  Architecture & Design   1990-01-17  True
# 87                 (Male)     1923  Architecture & Design   1990-01-17  True
# 88                 (Male)  Unknown  Architecture & Design   1990-01-17  True
# 89                 (Male)  Unknown  Architecture & Design   1990-01-17  True
# 90                 (Male)  Unknown  Architecture & Design   1990-01-17  True
# 91                 (Male)  Unknown  Architecture & Design   1990-01-17  True
# 92                 (Male)  Unknown  Architecture & Design   1990-01-17  True
# 93                 (Male)  Unknown  Architecture & Design   1990-01-17  True
# 94                 (Male)     1930  Architecture & Design   1990-01-17  True
# 95                 (Male)     1936  Architecture & Design   1990-01-17  True
# 96                 (Male)  Unknown  Architecture & Design   1990-01-17  True
# 97                 (Male)     1935  Architecture & Design   1990-01-17  True
# 98                 (Male)     1935  Architecture & Design   1990-01-17  True
# 99                 (Male)     1935  Architecture & Design   1990-01-17  True
# 100                (Male)     1935  Architecture & Design   1990-01-17  True
#
#     ThumbnailURL  Height (cm)  Width (cm)  YearAcquired
# 0           True      48.6000    168.9000          1996
# 1           True      40.6401     29.8451          1995
# 2           True      34.3000     31.8000          1997
# 3           True      50.8000     50.8000          1995
# 4           True      38.4000     19.1000          1997
# 5           True      35.6000     45.7000          1995
# 6           True      35.6000     45.7000          1995
# 7           True      35.6000     45.7000          1995
# 8           True      35.6000     45.7000          1995
# 9           True      35.6000     45.7000          1995
# 10          True      35.6000     45.7000          1995
# 11          True      35.6000     45.7000          1995
# 12          True      35.6000     45.7000          1995
# 13          True      35.6000     45.7000          1995
# 14          True      35.6000     45.7000          1995
# 15          True      35.6000     45.7000          1995
# 16          True      35.6000     45.7000          1995
# 17          True      35.6000     45.7000          1995
# 18          True      35.6000     45.7000          1995
# 19          True      35.6000     45.7000          1995
# 20          True      35.6000     45.7000          1995
# 21          True      35.6000     45.7000          1995
# 22          True      35.6000     45.7000          1995
# 23          True      35.6000     45.7000          1995
# 24          True      35.6000     45.7000          1995
# 25          True      35.6000     45.7000          1995
# 26          True      35.6000     45.7000          1995
# 27          True      35.6000     45.7000          1995
# 28          True      35.6000     45.7000          1995
# 29          True      35.6000     45.7000          1995
# ..           ...          ...         ...           ...
# 70          True      69.2151     99.6952          2000
# 71          True     112.7127    113.3477          1980
# 72          True      30.2000     30.2000          1980
# 73          True      59.7000     60.0000          1980
# 74          True      27.6000     27.3000          1980
# 75          True      20.3000     20.3000          1980
# 76          True      72.4000     91.4000          1980
# 78          True      23.2000     34.9000          1990
# 79          True      31.1000     61.9000          1990
# 80          True      31.8000     61.6000          1990
# 81          True      39.4000     34.0000          1990
# 82          True      57.2000     62.5000          1990
# 83          True      56.5000     62.2000          1990
# 84          True      56.8000     79.4000          1990
# 85          True      57.2000     79.1000          1990
# 86          True      47.9000     55.2000          1990
# 87          True      47.9000     55.5000          1990
# 88          True      33.0000     29.8000          1990
# 89          True      21.0000     26.7000          1990
# 90          True      91.4000     93.3000          1990
# 91          True      90.8000     93.0000          1990
# 92          True      90.2000     93.7000          1990
# 93          True      90.8000     90.8000          1990
# 94          True      52.7000     33.0000          1990
# 95          True      30.5000     70.5000          1990
# 96          True      39.4000     51.1000          1990
# 97          True      30.5000     83.5000          1990
# 98          True      30.8000     83.8000          1990
# 99          True      30.8000     83.5000          1990
# 100         True      30.8000     83.3000          1990
#
# [100 rows x 11 columns]

# %%
# Get data types.
artworks.dtypes
# Out:
# Artist           object
# Nationality      object
# Gender           object
# Date             object
# Department       object
# DateAcquired     object
# URL                bool
# ThumbnailURL       bool
# Height (cm)     float64
# Width (cm)      float64
# dtype: object

# %%
artworks['DateAcquired'] = pd.to_datetime(artworks.DateAcquired)
artworks['YearAcquired'] = artworks.DateAcquired.dt.year
artworks['YearAcquired'].dtype
# Out:
# dtype('int64')

# %%
# Remove multiple nationalities, genders, and artists.
artworks.loc[artworks['Gender'].str.contains('\) \('), 'Gender'] = '\(multiple_persons\)'
artworks.loc[artworks['Nationality'].str.contains('\) \('), 'Nationality'] = '\(multiple_nationalities\)'
artworks.loc[artworks['Artist'].str.contains(','), 'Artist'] = 'Multiple_Artists'

# Convert dates to start date, cutting down number of distinct examples.
artworks['Date'] = pd.Series(artworks.Date.str.extract(
    '([0-9]{4})', expand=False))[:-1]

# Final column drops and NA drop.
X = artworks.drop(['Department', 'DateAcquired', 'Artist', 'Nationality', 'Date'], 1)

# Create dummies separately.
artists = pd.get_dummies(artworks.Artist)
nationalities = pd.get_dummies(artworks.Nationality)
dates = pd.get_dummies(artworks.Date)

# Concat artists with other variables
X = pd.get_dummies(X, sparse=True)
X = pd.concat([X, nationalities, dates], axis=1)

Y = artworks.Department

# %%
# Alright! We've done our prep, let's build the model.
# Neural networks are hugely computationally intensive.
# This may take several minutes to run.

# Import the model.
from sklearn.neural_network import MLPClassifier

# Establish and fit the model, with a single, 1000 perceptron layer.
mlp = MLPClassifier(hidden_layer_sizes=(1000,))
mlp.fit(X, Y)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(1000,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)

# %%
mlp.score(X, Y)
# Out:
# 0.70527009478029967

# %%
Y.value_counts()/len(Y)
# Out:
# Prints & Illustrated Books    0.523811
# Photography                   0.225079
# Architecture & Design         0.112399
# Drawings                      0.103997
# Painting & Sculpture          0.034714
# Name: Department, dtype: float64

# %%
from sklearn.model_selection import cross_val_score
# Out:
# array([ 0.60579485,  0.69938948,  0.4706595 ,  0.53358209,  0.51613685])

# %%
# play around with different layers
# Establish and fit the model, with a single, 1000 perceptron layer.
mlp = MLPClassifier(hidden_layer_sizes=(1000,100,10))
mlp.fit(X, Y)
mlp.score(X, Y)
cross_val_score(mlp, X, Y, cv=5)
# Out:
# array([ 0.52376569,  0.52379107,  0.57915395,  0.52384183,  0.52384183])

# %%
# adjust the alpha values
mlp = MLPClassifier(hidden_layer_sizes=(1000,),alpha =.01)
mlp.fit(X, Y)
mlp.score(X, Y)
cross_val_score(mlp, X, Y, cv=5)
# Out:
# array([ 0.57517322,  0.66014149,  0.58269128,  0.48996899,  0.43356271])

# %%
# try changing the activation function for the hidden layer
# adjust the alpha values
mlp = MLPClassifier(hidden_layer_sizes=(1000,),activation ='logistic')
mlp.fit(X, Y)
mlp.score(X, Y)
cross_val_score(mlp, X, Y, cv=5)
# Out:
# array([ 0.60317845,  0.70064929,  0.57658574,  0.56784261,  0.52200039])

# %% [markdown]
# ### Conclusions:
# Only a few possible values were tested. Using a logistic activation function seemed to improve the original model.  Changing the alpha values and # and size of layers had a negative impact.
