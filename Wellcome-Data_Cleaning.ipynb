# %% [markdown]
# Using this dataset of article open-access prices paid by the WELLCOME Trust between 2012 and 2013
# 1. determine the five most common journals and the total articles for each.
# 2. Next, calculate the mean, median, and standard deviation of the open-access cost per article for each journal .
# 3. For a real bonus round, identify the open access prices paid by subject area.

# %% [markdown]
# Requirements for data clean up:
#
# Column A
# 1.	Substitute NA with an empty value (empty string)
# 2.	Replace anything with just a number with a PMC in front of it.
# 3.	Replace anything with PMC-number add PMCID: in front of
# Column B
#
# 1.	Substitute the abbreviation with real name
# Column C
# 1.	Replace abbreviation with the full name
# Column E
# 1.	Remove the pound symbol

# %%
import pandas as pd
import numpy as np

# %%
f = open('WELLCOME_APC.csv', encoding="latin-1")
df_input_file = pd.read_csv(f, sep=",")


result = df_input_file.shape
print("NUMBER OF ROWS AND COLUMNS:")
print(result)
print()
#
print("FILE INFORMATION:")
df_input_file.info()
print()
#
result = df_input_file.describe()
print("SUMMARY DESCRIPTIVE STATS FOR NUMERICAL COLUMNS:")
print(result)
print()
# Out:
# NUMBER OF ROWS AND COLUMNS:
# (2127, 5)
#
# FILE INFORMATION:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2127 entries, 0 to 2126
# Data columns (total 5 columns):
# PMID/PMCID                                             1928 non-null object
# Publisher                                              2127 non-null object
# Journal title                                          2126 non-null object
# Article title                                          2127 non-null object
# COST (£) charged to Wellcome (inc VAT when charged)    2127 non-null object
# dtypes: object(5)
# memory usage: 83.2+ KB
#
# SUMMARY DESCRIPTIVE STATS FOR NUMERICAL COLUMNS:
#                PMID/PMCID Publisher Journal title  \
# count                1928      2127          2126
# unique               1880       299           984
# top     Not yet available  Elsevier      PLoS One
# freq                    7       387            92
#
#                                             Article title  \
# count                                                2127
# unique                                               2126
# top     Exclusive breastfeeding, diarrhoel morbidity a...
# freq                                                    2
#
#        COST (£) charged to Wellcome (inc VAT when charged)
# count                                                2127
# unique                                               1402
# top                                              £2040.00
# freq                                                   94

# %%
result = df_input_file.apply(lambda x: sum(x.isnull()), axis=0)
print("MISSING VALUES (NAN) BY COLUMNS:")
print(result)
# Out:
# MISSING VALUES (NAN) BY COLUMNS:
# PMID/PMCID                                             199
# Publisher                                                0
# Journal title                                            1
# Article title                                            0
# COST (£) charged to Wellcome (inc VAT when charged)      0
# dtype: int64

# %%
df_input_file = df_input_file.fillna(value='')
result = df_input_file.apply(lambda x: sum(x.isnull()), axis=0)
print(result)
# Out:
# PMID/PMCID                                             0
# Publisher                                              0
# Journal title                                          0
# Article title                                          0
# COST (£) charged to Wellcome (inc VAT when charged)    0
# dtype: int64

# %%
df_input_file.head(n=3000)
# Out:
#                             PMID/PMCID  \
# 0
# 1                           PMC3679557
# 2                23043264  PMC3506128
# 3                  23438330 PMC3646402
# 4                 23438216 PMC3601604
# 5                           PMC3579457
# 6                           PMC3709265
# 7                 23057412 PMC3495574
# 8                    PMCID: PMC3780468
# 9                    PMCID: PMC3621575
# 10                   PMCID: PMC3739413
# 11                   PMCID: PMC3530961
# 12                   PMCID: PMC3624797
# 13                          PMC3413243
# 14                          PMC3694353
# 15                          PMC3572711
# 16                            22610094
# 17                   PMCID: PMC3586974
# 18        23455506  PMCID: PMC3607399
# 19          PMID: 24015914 PMC3833349
# 20                       : PMC3805332
# 21
# 22            PMCID:\n    PMC3656742\n
# 23                      PMCID: 3584654
# 24                 22971149 PMC3466778
# 25                            23072351
# 26                          PMC3477822
# 27                          PMC3530960
# 28                23458425 PMC3630740
# 29                      PMID: 20146481
# ...                                ...
# 2097                           3575693
# 2098        PMID: 22188548 PMC3492912
# 2099        PMID: 22764734 PMC3798095
# 2100                    PMID: 23703895
# 2101                 PMCID: PMC3664106
# 2102                    PMID: 23649934
# 2103                        PMC2955965
# 2104        PMID: 19948006 PMC3551259
# 2105                    PMID: 23305527
# 2106                 PMCID: PMC3600532
# 2107                        PMC3440570
# 2108              23670821 PMC3738939
# 2109                          23640856
# 2110                    PMID: 23918316
# 2111                 PMCID: PMC3728731
# 2112       23495205685.88 PMC3743159
# 2113         PMID:22997008 PMC3569869
# 2114                           3708104
# 2115                        PMC3713766
# 2116                        PMC3819359
# 2117                       PMC3773237
# 2118                       PMC3815011
# 2119                        PMC3805356
# 2120                             Epub
# 2121                        PMC3707567
# 2122                           2901593
# 2123                           3748854
# 2124                           3785148
# 2125          PMCID:\n    PMC3647051\n
# 2126  PMID: 23846567  (Epub July 2013)
#
#                                          Publisher  \
# 0                                              CUP
# 1                                              ACS
# 2                                              ACS
# 3                                              ACS
# 4                                              ACS
# 5                                              ACS
# 6                                              ACS
# 7                                              ACS
# 8     ACS (Amercian Chemical Society) Publications
# 9     ACS (Amercian Chemical Society) Publications
# 10    ACS (Amercian Chemical Society) Publications
# 11    ACS (Amercian Chemical Society) Publications
# 12    ACS (Amercian Chemical Society) Publications
# 13                                ACS Publications
# 14                                ACS Publications
# 15                                   AGA Institute
# 16                                           AMBSB
# 17           American Association of Immunologists
# 18           American Association of Immunologists
# 19                       American Chemical Society
# 20                       American Chemical Society
# 21                       American Chemical Society
# 22                       American Chemical Society
# 23                       AMERICAN CHEMICAL SOCIETY
# 24                       American Chemical Society
# 25                       American Chemical Society
# 26                       American Chemical Society
# 27                       American Chemical Society
# 28                       American Chemical Society
# 29                       American Chemical Society
# ...                                            ...
# 2097                               Wiley-Blackwell
# 2098                               Wiley-Blackwell
# 2099                               Wiley-Blackwell
# 2100                               Wiley-Blackwell
# 2101                               Wiley-Blackwell
# 2102                               Wiley-Blackwell
# 2103                               Wiley-Blackwell
# 2104                               Wiley-Blackwell
# 2105                               Wiley-Blackwell
# 2106                               Wiley-Blackwell
# 2107            Wiley-Blackwell, John Wiley & Sons
# 2108                                     Wiley-VCH
# 2109                                     Wiley-VCH
# 2110                                     Wiley-VCH
# 2111                                     Wiley-VCH
# 2112                                     Wiley-VCH
# 2113                                     Wiley-VCH
# 2114                               Wliey-Blackwell
# 2115                                Wolters Kluwer
# 2116                                Wolters Kluwer
# 2117                                Wolters Kluwer
# 2118                                Wolters Kluwer
# 2119                                Wolters Kluwer
# 2120                                Wolters Kluwer
# 2121                                Wolters Kluwer
# 2122                         Wolters Kluwer Health
# 2123                        Wolters Kluwer Health
# 2124                        Wolters Kluwer Health
# 2125                 Wolters Kluwer N.V./Lippinott
# 2126                               Wolters Kluwers
#
#                                           Journal title  \
# 0                                Psychological Medicine
# 1                                     Biomacromolecules
# 2                                            J Med Chem
# 3                                            J Med Chem
# 4                                            J Org Chem
# 5                        Journal of Medicinal Chemistry
# 6                          Journal of Proteome Research
# 7                                             Mol Pharm
# 8                                  ACS Chemical Biology
# 9                                  ACS Chemical Biology
# 10         Journal of Chemical Information and Modeling
# 11                       Journal of Medicinal Chemistry
# 12                       Journal of Medicinal Chemistry
# 13                                         Biochemistry
# 14                       Journal of Medicinal Chemistry
# 15                                     Gastroenterology
# 16                      Journal of Biological Chemistry
# 17                                Journal of Immunology
# 18                                Journal of Immunology
# 19                                 ACS Chemical Biology
# 20                                 ACS Chemical Biology
# 21                                 ACS Chemical Biology
# 22                            ACS Chemical Neuroscience
# 23                                             ACS NANO
# 24                            American Chemical Society
# 25                                 Analytical Chemistry
# 26                                 Analytical Chemistry
# 27                                 Analytical Chemistry
# 28                               Bioconjugate Chemistry
# 29                       Journal of Medicinal Chemistry
# ...                                                 ...
# 2097                             Molecular Microbiology
# 2098                                    Obesity Reviews
# 2099                                    Obesity Reviews
# 2100                             Statistics in Medicine
# 2101                                         Stem Cells
# 2102                                            Synapse
# 2103               The European Journal of Neuroscience
# 2104                                            Traffic
# 2105                                            Traffic
# 2106                         Zoonoses and Public Health
# 2107                American Journal of Transplantation
# 2108                                 Angew chems Int Ed
# 2109                                        CHEMBIOCHEM
# 2110                                        Chemmedchem
# 2111                                        Chemmedchem
# 2112                                        ChemMedChem
# 2113                                          Protemics
# 2114                   Journal of Small Animal Practice
# 2115                                               AIDS
# 2116                                       AIDS Journal
# 2117                                            AIDS UK
# 2118                                            AIDS UK
# 2119  JAIDS Journal of Acquired Immune Deficiency Sy...
# 2120  Journal of Acquired Immune Deficiency Syndroms...
# 2121                                    Journal of Aids
# 2122                               Circulation Research
# 2123                                               AIDS
# 2124                               Pediatr Infect Dis J
# 2125                                               AIDS
# 2126    Journal of Acquired Immune Deficiency Syndromes
#
#                                           Article title  \
# 0     Reduced parahippocampal cortical thickness in ...
# 1     Structural characterization of a Model Gram-ne...
# 2     Fumaroylamino-4,5-epoxymorphinans and related ...
# 3     Orvinols with mixed kappa/mu opioid receptor a...
# 4     Regioselective opening of myo-inositol orthoes...
# 5     Comparative Structural and Functional Studies ...
# 6     Mapping Proteolytic Processing in the Secretom...
# 7     Quantitative silencing of EGFP reporter gene b...
# 8     A Novel Allosteric Inhibitor of the Uridine Di...
# 9     Chemical proteomic analysis reveals the drugab...
# 10    Locating Sweet Spots for Screening Hits and Ev...
# 11    Synthesis and evaluation of ?-thymidine analog...
# 12    Discovery and structure-activity relationships...
# 13    Monomeric 14-3-3 has a chaperone-like activity...
# 14    Synthesis and in vitro and in vivo characteriz...
# 15    Much of the genetic risk of colorectal cancer ...
# 16                  Annexin-1 interaction with FPR2/ALX
# 17    Sialoadhesin ligand expression identifies a su...
# 18    Regulation of Foxp3+ Inducible Regulatory T Ce...
# 19    Discovery of an allosteric inhibitor binding s...
# 20    Synthesis of alpha-glucan in mycobacteria invo...
# 21    Discovery of ?2 Adrenergic Receptor Ligands Us...
# 22    Continuous online microdialysis using microflu...
# 23    HYDROXY-TERMINATED CONJUGATED POLYMER NANOPART...
# 24    Characterizing the Fatty Acid Binding Site in ...
# 25    Amphipathic polymers facilitate the study of f...
# 26    Quantitative dynamics of phosphorproteome: the...
# 27    Variable-Pitch Rectangular Cross-section Radio...
# 28    Design, synthesis and functional activity of l...
# 29    Toward biophysical probes for the 5-HT3 recept...
# ...                                                 ...
# 2097  Shigella IpaD has a Dual Role: Signal Transduc...
# 2098  Does maternal body mass index during pregnancy...
# 2099  Obesity and socioeconomic status in developing...
# 2100  Combining multiple imputation and meta-analysi...
# 2101  Matrix remodelling maintains ESC self-renewal ...
# 2102  Presynaptic pH and vesicle fusion in Drosophil...
# 2103  Hyperpolarization-activated ion channels as ta...
# 2104  Efficient internalization of MHC I requires ly...
# 2105  Proteomic analysis of clathrin interactions in...
# 2106  Ecology of zoonotic infectious diseases in bat...
# 2107  Low dose rapamycin treatment increases the abi...
# 2108  Design and synthesis of cyclic ADP-4-thioribos...
# 2109  A Prototypical Small-Molecule Modulator Uncoup...
# 2110  Structure-Activity Relationship Studies of Pyr...
# 2111  From On-Target to Off-Target Activity: Identif...
# 2112  Synthesis and structure-activity relationship ...
# 2113  Carbon source-induced reprogramming of the cel...
# 2114  Prevalence, outcome and risk factors for post-...
# 2115  HIV infected adolescents in Southern Africa ca...
# 2116  Short title: TB and VL breakthrough and failur...
# 2117   Sexual behaviour in a rural high HIV prevalence
# 2118  HIV incidence and survival from age-specific s...
# 2119  Accelerated biological ageing in HIV-infected ...
# 2120  Reduction in early mortality on antiretroviral...
# 2121  Risk factors for seropositivity to Kaposi sarc...
# 2122  Mechanistic Links Between Na+ Channel (SCN5A) ...
# 2123  Evaluation of an empiric risk screening score ...
# 2124  Topical umbilical cord care for prevention of ...
# 2125  Grassroots Community Organisations' Contributi...
# 2126  A novel community health worker tool outperfor...
#
#      COST (£) charged to Wellcome (inc VAT when charged)
# 0                                                 £0.00
# 1                                              £2381.04
# 2                                               £642.56
# 3                                               £669.64
# 4                                               £685.88
# 5                                              £2392.20
# 6                                              £2367.95
# 7                                               £649.33
# 8                                              £1294.59
# 9                                              £1294.78
# 10                                             £1329.69
# 11                                             £1287.20
# 12                                             £1324.66
# 13                                              £665.64
# 14                                             £1006.72
# 15                                              £238.08
# 16                                              £265.67
# 17                                             £2035.00
# 18                                             £3108.08
# 19                                             £1267.76
# 20                                             £2286.73
# 21                                              £947.07
# 22                                             £1186.80
# 23                                              £642.89
# 24                                             £1533.29
# 25                                             £2082.74
# 26                                             £2314.10
# 27                                              £759.67
# 28                                             £1565.26
# 29                                              £572.74
# ...                                                 ...
# 2097                                           £2236.02
# 2098                                           £2275.02
# 2099                                           £2373.57
# 2100                                            £791.19
# 2101                                           £1551.49
# 2102                                           £1961.68
# 2103                                           £1982.35
# 2104                                           £2239.22
# 2105                                           £2377.65
# 2106                                           £2272.15
# 2107                                           £1900.70
# 2108                                           £3026.17
# 2109                                           £1851.15
# 2110                                           £1812.89
# 2111                                           £1816.70
# 2112                                           £2168.05
# 2113                                           £1409.96
# 2114                                           £2400.00
# 2115                                           £1968.63
# 2116                                           £2015.72
# 2117                                           £1836.92
# 2118                                           £1836.92
# 2119                                           £1375.80
# 2120                                           £1836.92
# 2121                                           £2009.65
# 2122                                           £1334.15
# 2123                                           £1834.77
# 2124                                           £1834.77
# 2125                                           £2374.52
# 2126                                           £2034.75
#
# [2127 rows x 5 columns]

# %%
## Replace publisher name acronyms with full name
to_replace = {"mdpi":"Multidisciplinary Digital Publishing Institute" ,"cshlp": "cold spring harbor","Asbmc /cenveo": "American society for biochemistry and molecular biology","Npg": "Nature","Lww": "Lippincott Williams & Wilkins", "Bmj": "British Medical Association","Oxford University Press (OUP)": "Oxford University Press","PloS": "Public Library of Science", "PloS Public Library of Science": "Public Library of Science","AMBSB": "American Society for Biochemistry and Molecular Biology","ASBMB" :"American Society for Biochemistry and Molecular Biology", "CUP":"Cambridge University Press",\
              "AGA Institute": "American Gastroenterological Association" ,"BMC" :"BioMed Central",\
              "Nature Publishing": "Nature", "ACS" : "Amercian Chemical Society", "BPS" :"Biophysical Society", "CJS" :"Cadmus Journal Services", "FM" :"Frontiers Media", "ACS (Amercian Chemical Society) Publications": "American Chemical Society", "ACS Publications":"American Chemical Society"}

df_input_file["Publisher"].replace(to_replace, inplace=True)
df_input_file['Publisher'] = df_input_file['Publisher'].str.strip()
df_input_file['Publisher'] = df_input_file['Publisher'].str.lower()


df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'elsevier' if 'elsevier' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'elsevier' if 'elseveier' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'cold spring harbor' if 'cold spring' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'nature' if 'nature' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'springer' if 'springer' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'wiley' if 'wiley' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'blackwell' if 'blackwell' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'british medical association' if 'bmj' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'american society of biochemistry and molecular biology' if 'asbmb' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'public library of science' if 'plos' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'national academy of sciences' if 'pnas' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'national academy of sciences' if 'national academy of sciences' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'american society for microbiology' if 'asm' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'federation of american societies for experimental biology' if 'faseb' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'taylor & francis' if 'taylor' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'american society of biochemistry and molecular biology' if 'biochemistry and molecular biology' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'cambridge university press' if 'cambridge' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'oxford university press' if 'oxford' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'pubmed' if 'Pubmed' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'wolters kluwer' if 'wolters' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'company of biologists' if 'company of biologists' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'international union of crystallography' if 'union of crystallography' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'mary ann lieber' if 'ann lieber' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'institute of physics' if 'iop' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'massachussetts institute of technology' if 'mit' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'portland press' if 'portland' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'american chemical society' if 'american chemical society' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'taylor & francis' if 't&f' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'sage' if 'sage' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'sage' if 'pion' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'dartmouth journal services' if 'darmouth' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'hindawi publishing' if 'hindawi' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'the endocrine society' if 'endocrine' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'journal of medical internet research publications' if 'internet' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'society for general microbiology' if 'genermal microbiology' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'cadmus journal service' if 'cadmus' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'company of biologists' if 'biolgists' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'company of biologists' if 'company of biolgist' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'frontiers' if 'frontiers' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'american chemical society' if 'amercian chemical society' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'biophysical society' if 'byophysical society' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'biomed central' if 'biomed central' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'impact journals' if 'impact' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'scimed central' if 'jscimed central' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'royal society of chemistry' if 'rsc' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'future medicine' if 'future medicine' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'society of neuroscience' if 'society of neuro sciences' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'informa healthcare' if 'informa' in x else x)
df_input_file['Publisher'] = df_input_file['Publisher'].apply(lambda x: 'american society of hematology' if 'hamatology' in x else x)

publishers = list(df_input_file['Publisher'].copy())
print(set(publishers))
# Out:
# {'british medical journal', 'international union of crystallography', 'pubmed central', 'pubmed', 'american association of immunologists', 'american psychiatric publishing', 'society for general microbiology', 'society of leukocyte biology', 'biomed central', 'cadmus journal service', 'landes bioscience', 'the american society of pediatrics', 'society for publication of acta dermato-venereologica', 'cold spring harbor', 'optical society of america', 'royal society of chemistry', 'bentham science publishers', 'oxford university press', 'society of neuroscience', 'springer', 'royal college of psychiatrists', 'american society of biochemistry and molecular biology', 'camdus journal services', 'public library of science', 'policy press', 'the endocrine society', 'international union against tuberculosis and lung disease', 'bioscientifica', 'impact journals', 'journal of medical internet research publications', 'myjove corporation', 'mary ann lieber', 'my jove corporation', 'open access reg ltd', 'company of biologist', 'the american physiological society', 'university of the basque country press', 'asbmc /cenveo', 'cell press', 'association for research in vision & ophthalmology', 'landes biosciences', 'european society of endocrinolog', 'my jove corp', 'brill', 'sage', 'society for leukocyte biology', 'wolters kluwer', 'cambridge university press', 'palgrave macmillan', 'american speech-language-hearing association', 'the boulevard', 'federation of american societies for experimental biology', 'american society for investigative pathology', 'wiley', 'american chemical society', 'the endrocrine society', 'the royal college of psychiatrists', 'ios press', 'informa healthcare', 'frontiers', 'the sheridan press', 'elsevier', 'lww', 'american society of haematology', 'society of general microbiology', 'european respiratory society', 'benthan science publishers', 'american society for microbiology', 'society for neurosciences', 'oup', 'johns hopkins university press', 'coaction', 'society for endocrinology', 'research media ltd', 'biochem journal', 'jove', 'dartmouth journals', 'journal of visualized experiments', 'massachussetts institute of technology', 'american society for nutrition', 'nature', 'british medical association', 'hindawi publishing', 'ferrata storti foundation', 'international aids society', 'federation of the american society of experimental biology', 'npg', 'scimed central', 'american society for biochemistry and molecular biolgy', 'sheridan press', 'american psychiatric association', 'transcript verlag', 'royal society for chemistry', 'taylor & francis', 'american college of chest physicians', 'publisher society for endocrinology', 'multidisciplinary digital publishing institute', 'copyright clearace center', 'national academy of sciences', 'society for neuroscience', 'karger', 'the royal society', 'american society of microbiology', 'american physiological society', 'scientific research publishing', 'blackwell', 'macmillan', 'institute of physics', 'sciedu press', 'american psychological association', 'american society of hematology', 'future science', 'portland press', 'future medicine', 'american public health association', 'american gastroenterological association', 'berhahn books', 'cenveo publisher services', 'the journal of visualized experiments', 'royal society', 'dartmouth journal services', 'company of biologists', 'ivyspring international publisher', 'public.service.co.uk'}

# %%
df_input_file['COST (£) charged to Wellcome (inc VAT when charged)'] = df_input_file['COST (£) charged to Wellcome (inc VAT when charged)'].map(lambda x: str(x)[1:])
df_input_file['COST (£) charged to Wellcome (inc VAT when charged)'] = df_input_file['COST (£) charged to Wellcome (inc VAT when charged)'].str.replace('$','')
df_input_file['COST (£) charged to Wellcome (inc VAT when charged)'] = df_input_file['COST (£) charged to Wellcome (inc VAT when charged)'].astype(float)
df_input_file.head()
# Out:
#               PMID/PMCID                   Publisher           Journal title  \
# 0                         cambridge university press  psychological medicine
# 1             PMC3679557   american chemical society       biomacromolecules
# 2  23043264  PMC3506128    american chemical society              j med chem
# 3    23438330 PMC3646402   american chemical society              j med chem
# 4   23438216 PMC3601604    american chemical society              j org chem
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
#
#    COST (£) charged to Wellcome (inc VAT when charged)
# 0                                               0.00
# 1                                             381.04
# 2                                              42.56
# 3                                              69.64
# 4                                              85.88

# %%
df_input_file['Journal title'] = df_input_file['Journal title'].str.strip()
df_input_file['Journal title'] = df_input_file['Journal title'].str.lower()

df_input_file['Journal title'] = df_input_file['Journal title'].apply(lambda x: 'plos one' if 'plosone' in x else x)
df_input_file['Journal title'] = df_input_file['Journal title'].apply(lambda x: 'plos one' if 'plos 1' in x else x)
df_input_file['Journal title'] = df_input_file['Journal title'].apply(lambda x: 'journal of biological chemistry' if 'journal of biol chem' in x else x)
df_input_file['Journal title'] = df_input_file['Journal title'].apply(lambda x: 'journal of biological chemistry' if 'biological chemistry' in x else x)
df_input_file['Journal title'] = df_input_file['Journal title'].apply(lambda x: 'neuroimage' if 'neurolmage' in x else x)
df_input_file['Journal title'] = df_input_file['Journal title'].apply(lambda x: 'nucleic acids research' if 'nucleic acid research' in x else x)

journals = list(df_input_file['Journal title'].copy())
print(set(journals))
# Out:
# {'pain', '', 'genome research', 'j med chem.', 'cytoskeleton', 'neglected tropical disease', 'expert reviews in anti-infective chemotherapy', 'veterinary record', 'bba - molecular basis of disease', 'european journal of public health', 'bmc medical ethics', 'frontiers in endocrinology', 'evaluation in clinical practice', 'immunology', 'proceedings of the national academy of sciences of the united states of america', 'frontiers in decision neuroscience', 'journal of comparative neurology', 'molecular brain', 'cell journal', 'the lancet', 'trends in microbiology', 'immunological reviews', 'orphanet journal of rare diseases', 'clinical infectious diseases online', 'journal of internal medicine', 'bjophthalmol', 'plos negected tropical diseases', 'cell press - cell reports', 'european radiology', 'j infect dis', 'acta dermato venereologica', 'journal of psychopharmacology', 'analytical chemistry', 'age', 'journal of the international african institute', 'parasites and vectors', 'medical history', 'molecular phylogenetics and evolution', 'trials', 'health psychology', 'aids uk', 'vascular pharmacology', 'bone', 'thorax', 'journal of the royal statistical society: series c (applied statistics)', 'frontiers in human neuroscience', 'aids', 'stem cells', 'journal of immunology', 'journal of the royal society of medicine short reports', 'public service review', 'bmc genomics.', 'frontiers in behavioral neuroscience', 'european heart journal online', 'biology', 'biomolecular nmr assignments', 'veterinary research', 'trends in parasitology', 'future medicinal chemistry', 'trop med int health', 'american journal of human genetics', 'acs chemical biology', 'dalton transactions', 'journal of histochemistry & cytochemistry', 'translational psychiatry', 'journal of neurology', 'pone-d12-17947', 'social science and medicine', 'mbio', 'american journal of bioethics--neuroscience', 'molecular biology and evolution', 'tropical animal health & production', 'epilepsia', 'experimental hematology', 'the british journal of psychiatry', 'neurobiology of disease', 'biosystems', 'cell death and disease', 'learning and memory', 'human molecular genetics online', 'genome biology', 'channels', 'bmc genome biology', 'history of the human sciences', 'social science & medicine', 'hippocampus', 'gut', 'evidence, ethos and experiment: the anthropology and history of medical research in africa.', 'cell calcium', 'journal of virol', 'pmedicine-d-12-03130', 'cell reports', 'j mol biol', 'childs nerv syst', 'respiratory research', 'frontiers', 'bioinformatics', 'biophysical journal', 'journal of proteome research', 'neurology', 'american journal of transplantation', 'british jounal of pharmacology', 'journal of parasitology research', 'philosophical transactions of the royal society of london. series b, biological sciences', 'international journal of obesity', 'journal of biological physics', 'genes brain behaviour', 'behavioural brain research', 'nephrology dialysis transplantation', 'aids care', 'scientific reports', 'bmc pediatrics', 'public health', 'cell host and microbe', 'structure', 'journal of allergy & clinical immunology', 'bmc medical imaging', 'frontiers in cellular neuroscience', 'britsh journal of psychiatry', 'cancer research', 'acta crystallographica section d: biological crystallography', 'journal of molecular medicine', 'fems microbiology letters', 'psychological assessment', 'chromosome research', 'cognitive processing', 'epigenetics', 'journal of paediatric urology', 'springer science + business media', 'journal of cognitive neuroscience', 'biology letters', 'bmc genetics', 'international journal of developmental biology', 'plos medicine', 'j biol chemistry', 'vaccine', 'infection genetics and evolution', 'immnunobiology', 'animal behaviour', 'febs j.', 'journal of anthropological archaeology', 'bioethics', 'international journal of molecular sciences', 'microbes and infection', 'trends in molecular medicine', 'diabetic medicine', 'annals of scie ...

# %%
df_input_file.groupby('Journal title').size().sort_values(ascending=False).to_frame().head()
# Out:
#                                    0
# Journal title
# plos one                         206
# journal of biological chemistry   66
# neuroimage                        31
# nucleic acids research            29
# plos genetics                     24

# %%
df_input_file.groupby('Journal title')['COST (£) charged to Wellcome (inc VAT when charged)'].mean().to_frame().head()
# Out:
#                                                     COST (£) charged to Wellcome (inc VAT when charged)
# Journal title
# academy of nutrition and dietetics                                                           2379.540
# acs chemical biology                                                                         1418.186
# acs chemical neuroscience                                                                    1186.800
# acs nano                                                                                      668.140
# acta crystallographica section d,  biological c...                                            771.420

# %%
df_input_file.groupby('Journal title')['COST (£) charged to Wellcome (inc VAT when charged)'].median().to_frame().head()
# Out:
#                                                     COST (£) charged to Wellcome (inc VAT when charged)
# Journal title
# academy of nutrition and dietetics                                                            2379.54
# acs chemical biology                                                                          1294.59
# acs chemical neuroscience                                                                     1186.80
# acs nano                                                                                       668.14
# acta crystallographica section d,  biological c...                                             771.42

# %%
df_input_file.groupby('Journal title')['COST (£) charged to Wellcome (inc VAT when charged)'].std().to_frame().head()
# Out:
#                                                     COST (£) charged to Wellcome (inc VAT when charged)
# Journal title
# academy of nutrition and dietetics                                                                NaN
# acs chemical biology                                                                       507.309560
# acs chemical neuroscience                                                                         NaN
# acs nano                                                                                    35.708892
# acta crystallographica section d,  biological c...                                                NaN
